# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('../data/raw/X_train.csv')

# %%
data.columns
# Out:
# Index(['customer_unique_id', 'recency', 'total_payment', 'avg_installments',
#        'customer_city', 'customer_state', 'frequency', 'avg_review',
#        'churn_status'],
#       dtype='object')
