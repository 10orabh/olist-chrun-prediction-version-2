# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("D:/sourabh project/olist-chrun-prediction-version-2/data/raw/raw_data.csv")

# %%
df.head()
# Out:
#                  customer_unique_id  recency  total_payment  avg_installments  \
# 0  0000366f3b9a7992bf8c76cfdf3221e2     82.0         141.90               8.0
# 1  0000b849f77a49e4a4ce2b2a4ca5be3f     85.0          27.19               1.0
# 2  0000f46a3911fa3c0805444483337064    508.0          86.22               8.0
# 3  0000f6ccb0745a6a4b88665a16c9f078    292.0          43.62               4.0
# 4  0004aac84e0df4da2b147fca70cf8255    259.0         196.89               6.0
#
#   customer_city customer_state  is_repeat_purchase  churn_status
# 0       cajamar             SP                   0             0
# 1        osasco             SP                   0             0
# 2      sao jose             SC                   0             1
# 3         belem             PA                   0             1
# 4      sorocaba             SP                   0             1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87213 entries, 0 to 87212
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   customer_unique_id  87213 non-null  object
#  1   recency             87213 non-null  float64
#  2   total_payment       87213 non-null  float64
#  3   avg_installments    87213 non-null  float64
#  4   customer_city       87213 non-null  object
#  5   customer_state      87213 non-null  object
#  6   is_repeat_purchase  87213 non-null  int64
#  7   churn_status        87213 non-null  int64
# dtypes: float64(3), int64(2), object(3)
# memory usage: 5.3+ MB

# %%
df.describe()
# Out:
#             recency  total_payment  avg_installments  is_repeat_purchase  \
# count  87213.000000   87213.000000      87213.000000        87213.000000
# mean     224.342965     165.537792          2.909242            0.030053
# std      145.581721     226.491473          2.683380            0.170734
# min        0.000000      10.070000          0.000000            0.000000
# 25%      105.000000      63.120000          1.000000            0.000000
# 50%      203.000000     108.000000          2.000000            0.000000
# 75%      328.000000     182.910000          4.000000            0.000000
# max      666.000000   13664.080000         24.000000            1.000000
#
#        churn_status
# count  87213.000000
# mean       0.710697
# std        0.453442
# min        0.000000
# 25%        0.000000
# 50%        1.000000
# 75%        1.000000
# max        1.000000

# %%
plt.hist(df['recency'], bins=20)
plt.xlabel('Recency')
plt.ylabel('Frequency')
plt.title('Distribution of Recency')
plt.show()

# %%
plt.hist(df['total_payment'], bins=100)
plt.xlabel('Total Payment')
plt.ylabel('Frequency')
plt.title('Distribution of Total Payment')
plt.show()

# %%
df['churn_status'].value_counts().plot(kind='bar')
plt.xlabel('Churn Status')
plt.ylabel('Count')
plt.title('Distribution of Churn Status')
plt.show()
